# %% [markdown]
# # Deeplearning
# CBOW word2vec

# %%
import zipfile
import tensorflow as tf
import numpy as np
import random
import math
import collections

from matplotlib import pylab

# %%
# global variable
data_index = 0 # 采样时从文本的第一个词开始采样

def read_data(filename):
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
    
def build_dataset(vocabulary_size,words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reverse_dictionary
    
def generate_batch(data,batch_size,num_skips,skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    context_size = 2 * skip_window
    labels = np.ndarray(shape=(batch_size,1),dtype=np.int32)
    batchs = np.ndarray(shape=(context_size,batch_size),dtype=np.int32)
    span = 2 * skip_window + 1
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index+1)%(len(data))
    
    for i in range(batch_size//num_skips):
        target = skip_window
        for j in range(num_skips):
            labels[i * num_skips + j,0] = buffer[target]
            met_target = False
            for k in range(context_size):
                if k == target:
                    met_target = True
                if met_target == True:
                    batchs[k,i * num_skips + j] = buffer[k+1]
                else:
                    batchs[k,i * num_skips + j] = buffer[k]
        buffer.append(data[data_index])
        data_index = (data_index + 1)%len(data)
    return batchs,labels

# %%
filename="text8.zip"
vocabulary_size=50000
batch_size=8

print('...... Reading data from zip file......')
words = read_data(filename)
print('Data Size = {0}'.format(len(words)))
    
print('...... Transfer word data to word index,dictionary ......')
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary_size,words)
    
for num_skips,skip_window in [(1,1),(2,1),(4,2)]:
    data_index = 0
    batchs,labels = generate_batch(data,
                                  batch_size=batch_size,
                                  num_skips=num_skips,
                                  skip_window=skip_window
                                 )
    # TODO
    print('\n======With num_skips = {0} and skip_window = {1} ,context_size = {2}'.format(num_skips,skip_window,2*skip_window))
    print('    batch:',[reverse_dictionary[bi] for bi in batch[0]])
    print('    labels:',[reverse_dictionary[li] for li in labels.reshape(8)])
    for i in range(batch_size):
        context_size = 2 * skip_window
        for j in range(context_size):
            print(batch[j][i],'->',labels[i,0],'<===>',
                reverse_dictionary[batch[j][i]],'->',reverse_dictionary[labels[i,0]])
# Out:
# ...... Reading data from zip file......
# Data Size = 17005207
# ...... Transfer word data to word index,dictionary ......
#
# ======With num_skips = 1 and skip_window = 1 ,context_size = 2
# ('    batch:', ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first'])
# ('    labels:', ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used'])
# (5239, '->', 3084, '<===>', 'anarchism', '->', 'originated')
# (12, '->', 3084, '<===>', 'as', '->', 'originated')
# (3084, '->', 12, '<===>', 'originated', '->', 'as')
# (6, '->', 12, '<===>', 'a', '->', 'as')
# (12, '->', 6, '<===>', 'as', '->', 'a')
# (195, '->', 6, '<===>', 'term', '->', 'a')
# (6, '->', 195, '<===>', 'a', '->', 'term')
# (2, '->', 195, '<===>', 'of', '->', 'term')
# (195, '->', 2, '<===>', 'term', '->', 'of')
# (3137, '->', 2, '<===>', 'abuse', '->', 'of')
# (2, '->', 3137, '<===>', 'of', '->', 'abuse')
# (46, '->', 3137, '<===>', 'first', '->', 'abuse')
# (3137, '->', 46, '<===>', 'abuse', '->', 'first')
# (59, '->', 46, '<===>', 'used', '->', 'first')
# (46, '->', 59, '<===>', 'first', '->', 'used')
# (156, '->', 59, '<===>', 'against', '->', 'used')
#
# ======With num_skips = 2 and skip_window = 1 ,context_size = 2
# ('    batch:', ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first'])
# ('    labels:', ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term'])
# (5239, '->', 3084, '<===>', 'anarchism', '->', 'originated')
# (12, '->', 3084, '<===>', 'as', '->', 'originated')
# (3084, '->', 3084, '<===>', 'originated', '->', 'originated')
# (6, '->', 3084, '<===>', 'a', '->', 'originated')
# (12, '->', 12, '<===>', 'as', '->', 'as')
# (195, '->', 12, '<===>', 'term', '->', 'as')
# (6, '->', 12, '<===>', 'a', '->', 'as')
# (2, '->', 12, '<===>', 'of', '->', 'as')
# (195, '->', 6, '<===>', 'term', '->', 'a')
# (3137, '->', 6, '<===>', 'abuse', '->', 'a')
# (2, '->', 6, '<===>', 'of', '->', 'a')
# (46, '->', 6, '<===>', 'first', '->', 'a')
# (3137, '->', 195, '<===>', 'abuse', '->', 'term')
# (59, '->', 195, '<===>', 'used', '->', 'term')
# (46, '->', 195, '<===>', 'first', '->', 'term')
# (156, '->', 195, '<===>', 'against', '->', 'term')
#
# ======With num_skips = 4 and skip_window = 2 ,context_size = 4
# ('    batch:', ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first'])
# ('    labels:', ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a'])
# (5239, '->', 12, '<===>', 'anarchism', '->', 'as')
# (12, '->', 12, '<===>', 'as', '->', 'as')
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-de48ef27bc95> in <module>()
#      24         context_size = 2 * skip_window
#      25         for j in range(context_size):
# ---> 26             print(batch[j][i],'->',labels[i,0],'<===>',
#      27                 reverse_dictionary[batch[j][i]],'->',reverse_dictionary[labels[i,0]])
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %%
def train(filename="text8.zip",
          vocabulary_size=50000,
          embedding_size=128,# Dimension of the embedding vector
          batch_size=128,
          skip_window=1,# 上下文大小
          num_skips=2,# 每个词采样时作为中心词使用的次数)
          valid_size=16,# 随机选取的词的个数去评估模型
          valid_window=100,# 从当前词的前多少个选取测试样本
          num_sampled=64,# 负采样数
          num_steps=100001
          ):
    print('...... Reading data from zip file......')
    words = read_data(filename)
    print('Data Size = {0}'.format(len(words)))
    
    print('...... Transfer word data to word index,dictionary ......')
    data, count, dictionary, reverse_dictionary = build_dataset(vocabulary_size,words)
    
    print('...... Building model ......')
    valid_examples = np.array(random.sample(range(valid_window), valid_size))
    graph = tf.Graph()
    with graph.as_default(),tf.device('/cpu:0'):
        # Input data        
        train_dataset = tf.placeholder(tf.int32,shape=[2 * skip_window,batch_size])
        train_labels = tf.placeholder(tf.int32,shape=[batch_size,1])
        valid_dataset = tf.constant(valid_examples,shape=[2*skip_window,batch_size],dtype=tf.int32)
        
        # Varibles
        embeddings = tf.Variable(
            tf.random_uniform([vocabulary_size,embedding_size],-1.0,1.0)        
        )
        softmax_weights = tf.Variable(
            tf.truncated_normal([vocabulary_size,embedding_size],
                                stddev=1.0/math.sqrt(embedding_size))        
        )
        softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
        
        # Model
        embed = tf.nn.embedding_lookup(embeddings,train_dataset)
        embed_sum = tf.reduce_mean(embed,0)
        
        loss = tf.reduce_mean(
            tf.nn.sampled_softmax_loss(softmax_weights,softmax_biases,
                                       embed_sum,
                                       train_labels,num_sampled,vocabulary_size)        
        )
        
        optimizer = tf.train.AdadeltaOptimizer(1.0).minimize(loss)
        norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
        normalized_embeddings = embeddings / norm
        valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
        # sum up vectors
        valid_embeddings_sum = tf.reduce_sum(valid_embeddings, 0)
        similarity = tf.matmul(valid_embeddings_sum, tf.transpose(normalized_embeddings))
    
    print('...... Training......')
    with tf.Session(graph=graph) as session:
        tf.initialize_all_variables().run()
        average_loss = 0
        for step in range(num_steps):
            batch_data, batch_labels = generate_batch(data,
                batch_size, num_skips, skip_window)
            # print(batch_data.shape)
            # print(batch_labels.shape)
            feed_dict = {train_dataset: batch_data, train_labels: batch_labels}
            _, l = session.run([optimizer, loss], feed_dict=feed_dict)
            average_loss += l
            if step % 2000 == 0:
                if step > 0:
                    average_loss /= 2000
                # The average loss is an estimate of the loss over the last 2000 batches.
                print('Average loss at step %d: %f' % (step, average_loss))
                average_loss = 0
            # note that this is expensive (~20% slowdown if computed every 500 steps)
            if step % 10000 == 0:
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = reverse_dictionary[valid_examples[i]]
                    top_k = 8  # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = reverse_dictionary[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
        final_embeddings = normalized_embeddings.eval()
        save_obj("text8_cbow.pickle",final_embeddings)
    return final_embeddings,reverse_dictionary
        
        
def save_obj(pickle_file,obj):
    import cPickle as pickle
    import os
    try:
        f = open(pickle_file, 'wb')
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)
        f.close()
    except Exception as e:
        print('Unable to save data to', pickle_file, ':', e)
        raise
    statinfo = os.stat(pickle_file)
    print('Compressed pickle size:{0}MB'.format(statinfo.st_size/(1024.*1024.)))
    
def tsne_and_plot(num_points,
                  final_embeddings,
                  labels):
    tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
    two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points + 1, :])
    assert two_d_embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15, 15))  # in inches
    for i, label in enumerate(labels):
        x, y = two_d_embeddings[i, :]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

# %%
num_points = 400
final_embeddings,reverse_dictionary = train()

words = [reverse_dictionary[i] for i in range(1, num_points + 1)]
tsne_and_plot(num_points,final_embeddings,words)
# Out:
# ...... Reading data from zip file......
# Data Size = 17005207
# ...... Transfer word data to word index,dictionary ......
# ...... Building model ......
# ...... Training......
# Average loss at step 0: 7.732731
# Nearest to however: years, yury, buprenorphine, prequel, midland, polis, plethora, guillotined,
# Nearest to one: years, daisies, zoologists, temperance, expedition, knossos, diesels, commensurate,
# Nearest to state: years, royale, mandola, negotiating, revived, mayhew, quincey, measurable,
# Nearest to it: years, neglect, negotiating, seen, vacated, mode, dominions, moose,
# Nearest to new: years, zeeland, watched, mindfulness, cilicia, supernova, daisies, belisarius,
# Nearest to of: years, yury, pseudo, nkvd, hats, aucklanders, perihelion, gambler,
# Nearest to its: years, mindfulness, diesels, buckley, minimization, yury, preoccupied, epilogue,
# Nearest to no: years, ecm, reserving, schwarzenegger, banking, medically, braun, meatball,
# Nearest to about: years, sata, soldiery, likelihood, dickens, shattering, septimius, donn,
# Nearest to a: years, mindfulness, yan, baku, captivity, signify, citigroup, eighty,
# Nearest to system: years, aung, yury, ski, acting, beers, narn, apple,
# Nearest to two: years, safl, subplot, otherness, changed, perfect, mori, hungary,
# Nearest to this: years, mindfulness, affected, lifted, septimius, emergency, phillip, dickens,
# Nearest to history: years, browser, sweeping, reliable, confirming, regain, falcons, parthians,
# Nearest to when: when, expressionist, entourage, subplot, pacifist, turkey, hindi, overwhelm,
# Nearest to years: diesels, mindfulness, yury, septimius, negotiating, subplot, organometallic, dickens,
# Average loss at step 2000: 6.189972
# Average loss at step 4000: 5.068855
# Average loss at step 6000: 4.801409
# Average loss at step 8000: 4.452938
# Average loss at step 10000: 4.194211
# Nearest to however: years, midland, prequel, polis, amer, yury, borden, plethora,
# Nearest to one: years, the, a, UNK, two, and, earth, inadvertently,
# Nearest to state: years, revived, mandola, royale, negotiating, emergency, mayhew, quincey,
# Nearest to it: years, neglect, he, moose, UNK, pers, the, mode,
# Nearest to new: years, zeeland, passionate, watched, cilicia, ayckbourn, propensity, offa,
# Nearest to of: years, and, in, a, UNK, one, the, by,
# Nearest to its: its, mindfulness, fueled, diesels, excision, diagnostic, spectators, epilogue,
# Nearest to no: years, schwarzenegger, ecm, also, banking, sedatives, moorland, retreat,
# Nearest to about: years, soldiery, boitano, shattering, kl, valuation, cancelled, gustaf,
# Nearest to a: years, the, UNK, and, one, concord, s, bg,
# Nearest to system: system, narn, apple, aung, company, ski, retreat, saterland,
# Nearest to two: two, one, hungary, UNK, a, by, the, five,
# Nearest to this: years, endocarditis, a, dissociation, zeeland, profiles, ayckbourn, iea,
# Nearest to history: years, endocarditis, sedatives, reliable, emergency, variability, parthians, lattices,
# Nearest to when: years, only, barrister, vandal, entourage, zero, spoiled, pacifist,
# Nearest to years: mindfulness, septimius, emergency, horrified, diesels, polis, ayckbourn, negotiating,
# Average loss at step 12000: 4.135281
# Average loss at step 14000: 4.012628
# Average loss at step 16000: 3.754996
# Average loss at step 18000: 3.775222
# Average loss at step 20000: 3.898615
# Nearest to however: however, midland, prequel, amer, polis, read, plethora, designers,
# Nearest to one: years, a, UNK, two, and, the, by, in,
# Nearest to state: state, royale, revived, mandola, negotiating, emergency, rifts, apec,
# Nearest to it: it, he, UNK, the, one, this, and, a,
# Nearest to new: new, zeeland, passionate, propensity, offa, cilicia, ayckbourn, using,
# Nearest to of: years, and, in, by, for, a, one, UNK,
# Nearest to its: its, her, fueled, diagnostic, pers, rey, inadvertently, mindfulness,
# Nearest to no: years, schwarzenegger, also, ecm, moorland, retreat, been, safl,
# Nearest to about: years, soldiery, boitano, scheming, kl, only, world, cancelled,
# Nearest to a: years, the, UNK, and, one, this, s, was,
# Nearest to system: system, narn, apple, company, bubblegum, retreat, aung, ski,
# Nearest to two: two, one, UNK, by, a, the, and, many,
# Nearest to this: years, a, its, the, s, it, dissociation, zeeland,
# Nearest to history: history, endocarditis, sedatives, reliable, world, wallenberg, lattices, emergency,
# Nearest to when: when, only, barrister, vandal, spoiled, unstructured, zero, pacifist,
# Nearest to years: mindfulness, horrified, polis, ayckbourn, septimius, emergency, retreat, moose,
# Average loss at step 22000: 3.817889
# Average loss at step 24000: 3.767303
# Average loss at step 26000: 3.717909
# Average loss at step 28000: 3.674158
# Average loss at step 30000: 3.750043
# Nearest to however: however, midland, prequel, amer, read, designers, polis, other,
# Nearest to one: years, two, UNK, a, and, the, by, many,
# Nearest to state: state, royale, revived, mandola, negotiating, emergency, dari, ani,
# Nearest to it: years, he, the, this, UNK, its, and, a,
# Nearest to new: new, zeeland, propensity, passionate, offa, dissociation, using, cilicia,
# Nearest to of: of, and, for, by, in, s, a, or,
# Nearest to its: its, her, the, this, fueled, their, royale, a,
# Nearest to no: no, schwarzenegger, also, been, even, inadvertently, moorland, ecm,
# Nearest to about: about, soldiery, only, boitano, kl, scheming, world, cancelled,
# Nearest to a: years, the, this, UNK, and, one, s, their,
# Nearest to system: years, apple, company, area, narn, oh, bubblegum, ski,
# Nearest to two: two, one, by, UNK, a, the, many, was,
# Nearest to this: years, a, the, its, s, it, an, and,
# Nearest to history: history, endocarditis, sedatives, reliable, world, wallenberg, confusion, emergency,
# Nearest to when: years, only, barrister, vandal, displeasure, unstructured, pacifist, world,
# Nearest to years: mindfulness, horrified, polis, moose, septimius, emergency, ayckbourn, retreat,
# Average loss at step 32000: 3.706331
# Average loss at step 34000: 3.694788
# Average loss at step 36000: 3.670010
# Average loss at step 38000: 3.562070
# Average loss at step 40000: 3.629706
# Nearest to however: however, midland, prequel, amer, other, designers, only, never,
# Nearest to one: years, two, UNK, a, the, many, and, by,
# Nearest to state: state, royale, mandola, revived, emergency, name, negotiating, ani,
# Nearest to it: it, he, this, the, its, UNK, they, also,
# Nearest to new: new, zeeland, propensity, passionate, dissociation, offa, many, world,
# Nearest to of: of, this, for, and, or, its, s, by,
# Nearest to its: its, their, the, this, her, many, a, royale,
# Nearest to no: years, also, schwarzenegger, even, been, inadvertently, a, were,
# Nearest to about: about, only, soldiery, kl, world, scheming, boitano, cancelled,
# Nearest to a: years, the, this, their, its, UNK, s, was,
# Nearest to system: years, apple, area, company, oh, narn, ski, werewolf,
# Nearest to two: years, one, by, UNK, many, a, three, only,
# Nearest to this: years, the, a, its, s, it, their, many,
# Nearest to history: history, endocarditis, sedatives, reliable, world, wallenberg, confusion, only,
# Nearest to when: years, only, barrister, were, displeasure, vandal, time, world,
# Nearest to years: horrified, polis, mindfulness, septimius, moose, emergency, vandal, ayckbourn,
# Average loss at step 42000: 3.601416
# Average loss at step 44000: 3.594698
# Average loss at step 46000: 3.585026
# Average loss at step 48000: 3.514418
# Average loss at step 50000: 3.511281
# Nearest to however: however, midland, other, amer, prequel, designers, only, never,
# Nearest to one: one, two, UNK, many, its, a, this, also,
# Nearest to state: years, royale, mandola, revived, name, emergency, negotiating, ani,
# Nearest to it: years, he, this, its, the, they, only, also,
# Nearest to new: years, zeeland, propensity, passionate, world, many, offa, dissociation,
# Nearest to of: years, this, for, and, its, or, s, ingres,
# Nearest to its: years, their, the, this, her, many, a, royale,
# Nearest to no: no, also, schwarzenegger, even, been, a, their, inadvertently,
# Nearest to about: years, only, soldiery, world, kl, serialized, scheming, first,
# Nearest to a: a, the, their, this, its, many, litt, was,
# Nearest to system: system, apple, area, company, oh, even, werewolf, beers,
# Nearest to two: years, one, by, UNK, three, many, only, five,
# Nearest to this: this, its, the, a, it, their, s, many,
# Nearest to history: history, world, endocarditis, sedatives, reliable, confusion, only, use,
# Nearest to when: when, only, were, barrister, displeasure, while, world, time,
# Nearest to years: polis, horrified, mindfulness, moose, septimius, emergency, vandal, ayckbourn,
# Average loss at step 52000: 3.543472
# Average loss at step 54000: 3.554646
# Average loss at step 56000: 3.517061
# Average loss at step 58000: 3.497938
# Average loss at step 60000: 3.567439
# Nearest to however: however, midland, other, only, designers, amer, never, prequel,
# Nearest to one: years, two, many, UNK, also, its, lugh, first,
# Nearest to state: years, royale, mandola, name, revived, emergency, ani, negotiating,
# Nearest to it: years, he, this, its, they, only, also, the,
# Nearest to new: new, propensity, zeeland, world, passionate, many, offa, werewolf,
# Nearest to of: years, this, its, and, for, ingres, or, their,
# Nearest to its: years, their, the, her, this, many, royale, some,
# Nearest to no: years, also, even, schwarzenegger, a, been, their, first,
# Nearest to about: years, only, world, soldiery, kl, first, serialized, webcomic,
# Nearest to a: years, their, the, this, its, litt, many, first,
# Nearest to system: years, area, apple, company, name, even, oh, beers,
# Nearest to two: two, one, by, only, many, three, UNK, also,
# Nearest to this: years, its, the, a, it, their, which, many,
# Nearest to history: years, world, other, only, endocarditis, use, reliable, sedatives,
# Nearest to when: years, only, were, while, displeasure, if, barrister, world,
# Nearest to years: polis, horrified, mindfulness, emergency, septimius, moose, vandal, wiltshire,
# Average loss at step 62000: 3.434986
# Average loss at step 64000: 3.384624
# Average loss at step 66000: 3.505783
# Average loss at step 68000: 3.481289
# Average loss at step 70000: 3.433897
# Nearest to however: years, only, midland, other, never, designers, against, amer,
# Nearest to one: years, two, also, many, UNK, first, only, five,
# Nearest to state: years, royale, mandola, name, ani, revived, people, emergency,
# Nearest to it: years, he, this, its, only, they, also, but,
# Nearest to new: years, propensity, zeeland, world, passionate, many, offa, using,
# Nearest to of: years, this, ingres, its, for, and, many, or,
# Nearest to its: years, their, the, her, many, this, royale, some,
# Nearest to no: no, also, even, their, schwarzenegger, a, been, only,
# Nearest to about: years, only, world, kl, first, soldiery, dickens, serialized,
# Nearest to a: years, their, its, the, this, litt, many, first,
# Nearest to system: years, area, company, apple, name, even, beers, oh,
# Nearest to two: two, one, only, by, three, many, five, also,
# Nearest to this: years, its, their, a, the, it, which, many,
# Nearest to history: years, world, use, other, only, pale, endocarditis, reliable,
# Nearest to when: years, only, were, while, displeasure, if, world, time,
# Nearest to years: polis, horrified, emergency, septimius, mindfulness, moose, dickens, wiltshire,
# Average loss at step 72000: 3.450453
# Average loss at step 74000: 3.457321
# Average loss at step 76000: 3.475958
# Average loss at step 78000: 3.452843
# Average loss at step 80000: 3.444623
# Nearest to however: years, only, never, midland, when, against, other, will,
# Nearest to one: years, two, also, only, lugh, first, interjection, world,
# Nearest to state: years, royale, mandola, name, ani, people, city, emergency,
# Nearest to it: years, he, this, only, its, they, also, but,
# Nearest to new: years, propensity, zeeland, world, passionate, many, dickens, republic,
# Nearest to of: years, its, ingres, this, for, familiar, webcomic, many,
# Nearest to its: its, their, her, many, the, this, royale, litt,
# Nearest to no: no, also, even, their, a, schwarzenegger, its, only,
# Nearest to about: about, only, world, kl, first, webcomic, dickens, soldiery,
# Nearest to a: years, their, its, the, litt, this, first, many,
# Nearest to system: years, area, company, apple, name, even, state, beers,
# Nearest to two: two, one, only, three, by, also, many, five,
# Nearest to this: years, its, it, their, a, which, the, many,
# Nearest to history: years, world, use, other, hafez, only, pale, reliable,
# Nearest to when: years, only, while, were, if, displeasure, time, world,
# Nearest to years: polis, horrified, emergency, mindfulness, septimius, moose, dickens, wiltshire,
# Average loss at step 82000: 3.437977
# Average loss at step 84000: 3.438249
# Average loss at step 86000: 3.390977
# Average loss at step 88000: 3.377644
# Average loss at step 90000: 3.386913
# Nearest to however: years, only, when, midland, against, australian, never, but,
# Nearest to one: years, two, also, only, world, lugh, first, interjection,
# Nearest to state: years, royale, name, mandola, city, people, ani, emergency,
# Nearest to it: it, he, its, only, they, this, also, but,
# Nearest to new: new, propensity, zeeland, world, passionate, many, dickens, republic,
# Nearest to of: years, its, ingres, this, for, webcomic, and, their,
# Nearest to its: years, their, her, the, many, litt, some, royale,
# Nearest to no: years, also, even, a, their, only, its, first,
# Nearest to about: years, only, world, kl, webcomic, first, dickens, over,
# Nearest to a: years, their, its, the, litt, this, first, many,
# Nearest to system: system, area, company, apple, name, state, even, because,
# Nearest to two: two, one, only, three, by, also, name, english,
# Nearest to this: years, its, their, it, a, the, which, many,
# Nearest to history: history, world, use, other, hafez, pale, only, out,
# Nearest to when: years, while, only, were, if, displeasure, time, world,
# Nearest to years: polis, horrified, emergency, mindfulness, septimius, wiltshire, moose, distillers,
# Average loss at step 92000: 3.417217
# Average loss at step 94000: 3.313586
# Average loss at step 96000: 3.362511
# Average loss at step 98000: 3.281249
# Average loss at step 100000: 3.363085
# Nearest to however: years, when, only, against, but, including, australian, midland,
# Nearest to one: years, two, also, name, lugh, university, only, world,
# Nearest to state: years, royale, name, mandola, city, ani, people, emergency,
# Nearest to it: years, he, only, its, they, this, also, out,
# Nearest to new: years, propensity, zeeland, world, dickens, many, passionate, republic,
# Nearest to of: years, its, ingres, webcomic, and, this, for, genocide,
# Nearest to its: its, their, her, the, many, litt, his, some,
# Nearest to no: years, also, a, even, their, only, its, several,
# Nearest to about: about, only, world, webcomic, kl, against, dickens, up,
# Nearest to a: years, their, its, the, litt, first, this, aggressiveness,
# Nearest to system: years, area, company, apple, name, state, even, beers,
# Nearest to two: years, one, only, three, six, name, by, many,
# Nearest to this: years, its, it, their, a, which, the, many,
# Nearest to history: years, use, world, hafez, pale, other, out, reliable,
# Nearest to when: years, while, if, were, only, displeasure, against, until,
# Nearest to years: polis, horrified, mindfulness, emergency, septimius, distillers, wiltshire, moose,
# Compressed pickle size:24.414191246MB
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-b4a359a8c5c0> in <module>()
#       3
#       4 words = [reverse_dictionary[i] for i in range(1, num_points + 1)]
# ----> 5 tsne_and_plot(num_points,final_embeddings,words)
#
# <ipython-input-10-990dc2f255ac> in tsne_and_plot(num_points, final_embeddings, labels)
#     105                   final_embeddings,
#     106                   labels):
# --> 107     tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
#     108     two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points + 1, :])
#     109     assert two_d_embeddings.shape[0] >= len(labels), 'More labels than embeddings'
#
# NameError: global name 'TSNE' is not defined
